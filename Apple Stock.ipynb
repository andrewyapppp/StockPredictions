# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pt
from statsmodels.tsa.stattools import adfuller
from scipy import stats
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
data = pd.read_csv('C:/Users/Drew/Documents/Datasets/Consumer Electronics/apple_stock.csv')

# %%
data.set_index('Date', inplace=True)

# %%
data.head(20)
# Out:
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2014-01-02  19.845715  19.893929  19.715000  19.754642  17.318729   234684800
# 2014-01-03  19.745001  19.775000  19.301071  19.320715  16.938305   392467600
# 2014-01-06  19.194643  19.528570  19.057142  19.426071  17.030676   412610800
# 2014-01-07  19.440001  19.498571  19.211430  19.287144  16.908880   317209200
# 2014-01-08  19.243214  19.484285  19.238930  19.409286  17.015959   258529600
# 2014-01-09  19.528570  19.530714  19.119642  19.161428  16.798664   279148800
# 2014-01-10  19.279642  19.314285  18.968214  19.033571  16.686569   304976000
# 2014-01-13  18.925358  19.375000  18.924286  19.133215  16.773926   378492800
# 2014-01-14  19.222143  19.526072  19.202143  19.513929  17.107697   332561600
# 2014-01-15  19.768572  20.007143  19.702143  19.905714  17.451174   391638800
# 2014-01-16  19.817858  19.887501  19.702856  19.794643  17.353794   229278000
# 2014-01-17  19.695715  19.716785  19.282143  19.309643  16.928598   426739600
# 2014-01-21  19.321072  19.645357  19.300714  19.609644  17.191607   328526800
# 2014-01-22  19.675358  19.903214  19.564644  19.696787  17.268011   379985200
# 2014-01-23  19.640715  19.875000  19.457500  19.863571  17.414225   403239200
# 2014-01-24  19.785713  19.843571  19.455357  19.502501  17.097681   429354800
# 2014-01-27  19.645357  19.814285  19.491072  19.660713  17.236378   554878800
# 2014-01-28  18.170000  18.392857  17.931070  18.089287  15.858727  1065523200
# 2014-01-29  17.998215  18.120358  17.807858  17.883928  15.678684   502810000
# 2014-01-30  17.947857  18.089287  17.739286  17.849285  15.648315   678501600

# %%
pd.to_datetime(data.index)
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-14', '2014-01-15',
#                ...
#                '2023-10-18', '2023-10-19', '2023-10-20', '2023-10-23',
#                '2023-10-24', '2023-10-25', '2023-10-26', '2023-10-27',
#                '2023-10-30', '2023-10-31'],
#               dtype='datetime64[ns]', name='Date', length=2475, freq=None)

# %%
data.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2475 entries, 2014-01-02 to 2023-10-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2475 non-null   float64
#  1   High       2475 non-null   float64
#  2   Low        2475 non-null   float64
#  3   Close      2475 non-null   float64
#  4   Adj Close  2475 non-null   float64
#  5   Volume     2475 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 135.4+ KB

# %% [markdown]
# # Data Visualization

# %%
fig, ax = pt.subplots(figsize=(15,8))

ax.plot(data['Adj Close'], label='Adj Close')
ax.set_title('Adjusted Close Price of Apple')
ax.set_xlabel('Time')
ax.set_ylabel('Value')
fig.autofmt_xdate()
pt.xticks(np.arange(0,2475,100))
pt.tight_layout()

# %% [markdown]
# There is a increasing trend

# %%
fig, ax = pt.subplots(figsize=(15,8))

ax.plot(data['Volume'], label='Volume')
ax.set_title('Volume of Apple')
ax.set_xlabel('Time')
ax.set_ylabel('Value')
fig.autofmt_xdate()
pt.xticks(np.arange(0,2475,100))
pt.tight_layout()

# %% [markdown]
# It seems that the volume of this stock is slowly decreasing

# %%
xi = np.arange(0,2475)
y = data['Adj Close']

slope, intercept, r_value, p_value, std_err = stats.linregress(xi,y)

print('R-Value: ' , r_value)
print('P-Value: ' , p_value)
print('Std Err: ' , std_err)

line = slope*xi  + intercept
pt.plot(xi, line, 'r', xi, y, 'o')
pt.show()
# Out:
# R-Value:  0.9226372199067167
# P-Value:  0.0
# Std Err:  0.0005995818031637011

# %%
std_dev = data['Adj Close'].std()
print(f' Standard Deviation: {std_dev}')

mean = np.mean(data['Adj Close'])
print(f' Mean: {mean}')

coef_var = (std_dev / mean)*100
print(f' Coefficient Variance: {coef_var} %')
# Out:
#  Standard Deviation: 55.248195027037944
#  Mean: 74.09712394483162
#  Coefficient Variance: 74.56186162930226 %

# %% [markdown]
# # Moving Average Window

# %%
data['Moving Average (10)'] = data['Adj Close'].rolling(window=10).mean()
data['Moving Average (30)'] = data['Adj Close'].rolling(window=30).mean()
data['Moving Average (50)'] = data['Adj Close'].rolling(window=50).mean()
data['Moving Average (100)'] = data['Adj Close'].rolling(window=100).mean()

# %%
data.head(20)
# Out:
#                  Open       High        Low      Close  Adj Close      Volume  \
# Date
# 2014-01-02  19.845715  19.893929  19.715000  19.754642  17.318729   234684800
# 2014-01-03  19.745001  19.775000  19.301071  19.320715  16.938305   392467600
# 2014-01-06  19.194643  19.528570  19.057142  19.426071  17.030676   412610800
# 2014-01-07  19.440001  19.498571  19.211430  19.287144  16.908880   317209200
# 2014-01-08  19.243214  19.484285  19.238930  19.409286  17.015959   258529600
# 2014-01-09  19.528570  19.530714  19.119642  19.161428  16.798664   279148800
# 2014-01-10  19.279642  19.314285  18.968214  19.033571  16.686569   304976000
# 2014-01-13  18.925358  19.375000  18.924286  19.133215  16.773926   378492800
# 2014-01-14  19.222143  19.526072  19.202143  19.513929  17.107697   332561600
# 2014-01-15  19.768572  20.007143  19.702143  19.905714  17.451174   391638800
# 2014-01-16  19.817858  19.887501  19.702856  19.794643  17.353794   229278000
# 2014-01-17  19.695715  19.716785  19.282143  19.309643  16.928598   426739600
# 2014-01-21  19.321072  19.645357  19.300714  19.609644  17.191607   328526800
# 2014-01-22  19.675358  19.903214  19.564644  19.696787  17.268011   379985200
# 2014-01-23  19.640715  19.875000  19.457500  19.863571  17.414225   403239200
# 2014-01-24  19.785713  19.843571  19.455357  19.502501  17.097681   429354800
# 2014-01-27  19.645357  19.814285  19.491072  19.660713  17.236378   554878800
# 2014-01-28  18.170000  18.392857  17.931070  18.089287  15.858727  1065523200
# 2014-01-29  17.998215  18.120358  17.807858  17.883928  15.678684   502810000
# 2014-01-30  17.947857  18.089287  17.739286  17.849285  15.648315   678501600
#
#             Moving Average (10)  Moving Average (30)  Moving Average (50)  \
# Date
# 2014-01-02                  NaN                  NaN                  NaN
# 2014-01-03                  NaN                  NaN                  NaN
# 2014-01-06                  NaN                  NaN                  NaN
# 2014-01-07                  NaN                  NaN                  NaN
# 2014-01-08                  NaN                  NaN                  NaN
# 2014-01-09                  NaN                  NaN                  NaN
# 2014-01-10                  NaN                  NaN                  NaN
# 2014-01-13                  NaN                  NaN                  NaN
# 2014-01-14                  NaN                  NaN                  NaN
# 2014-01-15            17.003058                  NaN                  NaN
# 2014-01-16            17.006564                  NaN                  NaN
# 2014-01-17            17.005594                  NaN                  NaN
# 2014-01-21            17.021687                  NaN                  NaN
# 2014-01-22            17.057600                  NaN                  NaN
# 2014-01-23            17.097426                  NaN                  NaN
# 2014-01-24            17.127328                  NaN                  NaN
# 2014-01-27            17.182309                  NaN                  NaN
# 2014-01-28            17.090789                  NaN                  NaN
# 2014-01-29            16.947888                  NaN                  NaN
# 2014-01-30            16.767602                  NaN                  NaN
#
#             Moving Average (100)
# Date
# 2014-01-02                   NaN
# 2014-01-03                   NaN
# 2014-01-06                   NaN
# 2014-01-07                   NaN
# 2014-01-08                   NaN
# 2014-01-09                   NaN
# 2014-01-10                   NaN
# 2014-01-13                   NaN
# 2014-01-14                   NaN
# 2014-01-15                   NaN
# 2014-01-16                   NaN
# 2014-01-17                   NaN
# 2014-01-21                   NaN
# 2014-01-22                   NaN
# 2014-01-23                   NaN
# 2014-01-24                   NaN
# 2014-01-27                   NaN
# 2014-01-28                   NaN
# 2014-01-29                   NaN
# 2014-01-30                   NaN

# %%
fig, ax = pt.subplots(figsize=(10,8))

ax.plot(data['Adj Close'], 'b.', label='Adj Close')
ax.plot(data['Moving Average (30)'], 'r-', label='MA (30)', linewidth=3)
ax.plot(data['Moving Average (50)'], 'k-',label='MA (50)', linewidth=3)
ax.plot(data['Moving Average (100)'], 'g-',label='MA (100)', linewidth=3)
ax.set_title('Price Movement')
ax.set_xlabel('Time')
ax.set_ylabel('Value')
ax.legend(loc=2)
pt.xticks(np.arange(0,2475, 100))
fig.autofmt_xdate()
pt.tight_layout()

# %%
fig, ax = pt.subplots(figsize=(10,8))

ax.plot(data['Adj Close'], 'b.', label='Adj Close')
moving_average_30 = data['Adj Close'].rolling(window=30, center=True).std()
moving_average_50 = data['Adj Close'].rolling(window=50, center=True).std()
moving_average_100 = data['Adj Close'].rolling(window=100, center=True).std()
ax.plot(moving_average_30, 'r-', label='MA (30)', linewidth=3)
ax.plot(moving_average_50, 'k-',label='MA (50)', linewidth=3)
ax.plot(moving_average_100, 'g-',label='MA (100)', linewidth=3)

ax.set_title('Rolling Standard Deviation Price Movement')
ax.set_xlabel('Time')
ax.set_ylabel('Value')
ax.legend(loc=2)
pt.xticks(np.arange(0,2475, 100))
fig.autofmt_xdate()
pt.tight_layout()

# %% [markdown]
# The standard deviation is fairly constant

# %% [markdown]
# pct_change() in this case is basically calculating the percentage change of the current element from previous element. In this case, Adj Close price the current day and the previous day.

# %%
data['Daily Return'] = data['Adj Close'].pct_change()
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2014-01-02  19.845715  19.893929  19.715000  19.754642  17.318729  234684800
# 2014-01-03  19.745001  19.775000  19.301071  19.320715  16.938305  392467600
# 2014-01-06  19.194643  19.528570  19.057142  19.426071  17.030676  412610800
# 2014-01-07  19.440001  19.498571  19.211430  19.287144  16.908880  317209200
# 2014-01-08  19.243214  19.484285  19.238930  19.409286  17.015959  258529600
#
#             Moving Average (10)  Moving Average (30)  Moving Average (50)  \
# Date
# 2014-01-02                  NaN                  NaN                  NaN
# 2014-01-03                  NaN                  NaN                  NaN
# 2014-01-06                  NaN                  NaN                  NaN
# 2014-01-07                  NaN                  NaN                  NaN
# 2014-01-08                  NaN                  NaN                  NaN
#
#             Moving Average (100)  Daily Return
# Date
# 2014-01-02                   NaN           NaN
# 2014-01-03                   NaN     -0.021966
# 2014-01-06                   NaN      0.005453
# 2014-01-07                   NaN     -0.007152
# 2014-01-08                   NaN      0.006333

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-10-25  171.880005  173.059998  170.649994  171.100006  170.874893
# 2023-10-26  170.369995  171.380005  165.669998  166.889999  166.670425
# 2023-10-27  166.910004  168.960007  166.830002  168.220001  167.998672
# 2023-10-30  169.020004  171.169998  168.869995  170.289993  170.065933
# 2023-10-31  169.350006  170.899994  167.899994  170.770004  170.545319
#
#               Volume  Moving Average (10)  Moving Average (30)  \
# Date
# 2023-10-25  57157000           175.483813           175.066360
# 2023-10-26  70625300           174.103632           174.771748
# 2023-10-27  58499100           173.042030           174.545713
# 2023-10-30  51131000           172.200137           174.290050
# 2023-10-31  44846000           171.562978           174.013747
#
#             Moving Average (50)  Moving Average (100)  Daily Return
# Date
# 2023-10-25           176.980039            181.927798     -0.013492
# 2023-10-26           176.786694            181.803484     -0.024606
# 2023-10-27           176.671246            181.696142      0.007969
# 2023-10-30           176.587356            181.623336      0.012305
# 2023-10-31           176.486089            181.527896      0.002819

# %%
fig, ax = pt.subplots(figsize=(10,8))

ax.plot(data['Daily Return'], label='Daily Return')
ax.set_title('Daily Return')
ax.set_xlabel('Time')
ax.set_ylabel('Value')
pt.xticks(np.arange(0,2475,200))
fig.autofmt_xdate()
pt.tight_layout()

# %% [markdown]
# # XGBoosting For Feature Importance

# %%
Features = ['Open', 'High', 'Low', 'Close', 'Volume']
target = ['Adj Close']

# %%
train = data.loc[data.index < '2022-10-31']
test = data.loc[data.index > '2022-10-31']

# %%
fig, ax = pt.subplots(figsize=(10,8))

ax.plot(train[target], label='Train')
ax.plot(test[target], label='Test')
ax.set_xlabel('Date')
ax.set_ylabel('Value')
ax.legend(loc=2)
pt.xticks(np.arange(0,2475,200))
fig.autofmt_xdate()
pt.tight_layout()

# %%
X_train = train[Features]
y_train = train[target]

X_test = test[Features]
y_test = test[target]

# %%
reg = xgb.XGBRegressor(n_estimators=1000, early_stopping_rounds=50, learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:47.87503	validation_1-rmse:100.90673
# [100]	validation_0-rmse:17.72489	validation_1-rmse:41.56720
# [200]	validation_0-rmse:6.58322	validation_1-rmse:19.05595
# [300]	validation_0-rmse:2.47381	validation_1-rmse:10.53377
# [400]	validation_0-rmse:0.97745	validation_1-rmse:7.26079
# [500]	validation_0-rmse:0.47253	validation_1-rmse:6.25654
# [600]	validation_0-rmse:0.33256	validation_1-rmse:5.91713
# [700]	validation_0-rmse:0.29662	validation_1-rmse:5.79012
# [800]	validation_0-rmse:0.28169	validation_1-rmse:5.73757
# [900]	validation_0-rmse:0.27373	validation_1-rmse:5.71225
# [999]	validation_0-rmse:0.26814	validation_1-rmse:5.69541
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
feature_importance = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['Importances'])

# %%
feature_importance.sort_values('Importances').plot(kind='barh', title='Feature Importance')
# Out:
# <Axes: title={'center': 'Feature Importance'}>

# %%
feature_importance
# Out:
#         Importances
# Open       0.030626
# High       0.601108
# Low        0.012028
# Close      0.356227
# Volume     0.000011

# %% [markdown]
# The Highest price of the day and the closing price of the day is relevant to our Adjusted Closing Price

# %% [markdown]
# # Stationary Check

# %%
adf_results = adfuller(data['Adj Close'])
print(f' ADF Statistic: {adf_results[0]}')
print(f' P-Value: {adf_results[1]}')
# Out:
#  ADF Statistic: -0.1001816367976703
#  P-Value: 0.9494204387615286

# %%
adf_results = adfuller(np.diff(data['Adj Close'], n=1))
print(f' ADF Statistic: {adf_results[0]}')

if adf_results[1] < 0.05:
    print(f' P-Value: {adf_results[1]}')
    print(' The time series is stationary')
else:
    print('The Time Series is not stationary')
# Out:
#  ADF Statistic: -11.323135814699944
#  P-Value: 1.160855571737269e-20
#  The time series is stationary

# %%
data_diff = np.diff(data['Adj Close'], n=1)

# %%
fig, ax = pt.subplots(figsize=(10,8))

ax.plot(data_diff)
ax.set_title('Stationarity')
fig.autofmt_xdate()
pt.tight_layout()

# %% [markdown]
# First order integration

# %%
plot_acf(data['Adj Close'], lags=20)
print(plot_acf)
# Out:
# <function plot_acf at 0x000001C9FAFD49A0>

# %%
plot_pacf(data['Adj Close'], lags=20)
print(plot_pacf)
# Out:
# <function plot_pacf at 0x000001C9FAFD4860>

# %% [markdown]
# # Data Preprocessing

# %%
copy_data = data.copy()

# %%
copy_data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2014-01-02  19.845715  19.893929  19.715000  19.754642  17.318729  234684800
# 2014-01-03  19.745001  19.775000  19.301071  19.320715  16.938305  392467600
# 2014-01-06  19.194643  19.528570  19.057142  19.426071  17.030676  412610800
# 2014-01-07  19.440001  19.498571  19.211430  19.287144  16.908880  317209200
# 2014-01-08  19.243214  19.484285  19.238930  19.409286  17.015959  258529600
#
#             Moving Average (10)  Moving Average (30)  Moving Average (50)  \
# Date
# 2014-01-02                  NaN                  NaN                  NaN
# 2014-01-03                  NaN                  NaN                  NaN
# 2014-01-06                  NaN                  NaN                  NaN
# 2014-01-07                  NaN                  NaN                  NaN
# 2014-01-08                  NaN                  NaN                  NaN
#
#             Moving Average (100)  Daily Return
# Date
# 2014-01-02                   NaN           NaN
# 2014-01-03                   NaN     -0.021966
# 2014-01-06                   NaN      0.005453
# 2014-01-07                   NaN     -0.007152
# 2014-01-08                   NaN      0.006333

# %%
copy_data.drop(['Open', 
           'Low', 
           'Volume',
           'Moving Average (10)', 
           'Moving Average (30)', 
           'Moving Average (50)', 
           'Moving Average (100)', 
           'Daily Return'], inplace=True,axis=1)

# %%
copy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2475 entries, 2014-01-02 to 2023-10-31
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       2475 non-null   float64
#  1   Close      2475 non-null   float64
#  2   Adj Close  2475 non-null   float64
# dtypes: float64(3)
# memory usage: 77.3+ KB

# %%
scaler = StandardScaler()
scaler.fit(copy_data)
copy_data = scaler.transform(copy_data)

# %%
copy_data
# Out:
# array([[-1.02840831, -1.02798692, -1.0279045 ],
#        [-1.03055587, -1.0359087 , -1.03479163],
#        [-1.03500578, -1.03398532, -1.03311936],
#        ...,
#        [ 1.66335869,  1.68239575,  1.69997453],
#        [ 1.7032657 ,  1.72018552,  1.7373998 ],
#        [ 1.69839009,  1.72894859,  1.74607849]])

# %%
pca = PCA(n_components=1)
copy_data = pca.fit_transform(copy_data)

# %%
copy_data
# Out:
# array([[-1.78072127],
#        [-1.79051119],
#        [-1.79100429],
#        ...,
#        [ 2.91315341],
#        [ 2.97961912],
#        [ 2.98687444]])

# %% [markdown]
# # Model Selection

# %%
from typing import Union
from tqdm import tqdm_notebook
from statsmodels.tsa.statespace.sarimax import SARIMAX

def optimize_ARIMA(endog: Union[pd.Series, list], order_list: list, d: int) -> pd.DataFrame:
    results = []  # Initialize an empty list to store results
    for order in tqdm_notebook(order_list):  # Iterate over each unique (p,q) combination. Tqdm_notebook will display a progress bar.
        try:
            # Fit an ARIMA(p,d,q) model using the SARIMAX function.
            model = SARIMAX(endog, order=(order[0], d, order[1]), simple_differencing=False).fit(disp=False)
            aic = model.aic  # Calculate the model AIC
            results.append([order, aic])
        except Exception as e:
            print(f"Error fitting SARIMAX with order {order}: {e}")
            continue

    if not results:
        print("No models were successfully fitted.")
        return pd.DataFrame()  # Return an empty DataFrame if no models were fitted

    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)', 'AIC']

    # Sorting the results in ascending order. The lower the AIC, the better.
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)

    return result_df

# %%
from itertools import product

ps = range(0,4,1)
qs = range(0,4,1)
d = 1

arima_list = list(product(ps,qs))

# %%
train = copy_data[:-261]
test = copy_data[-261:]

# %%
train.shape
# Out:
# (2214, 1)

# %%
test.shape
# Out:
# (261, 1)

# %%
results = optimize_ARIMA(train, arima_list, d)
results
# Out:
# C:\Users\Drew\AppData\Local\Temp\ipykernel_44276\1285813300.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for order in tqdm_notebook(order_list):  # Iterate over each unique (p,q) combination. Tqdm_notebook will display a progress bar.
#   0%|          | 0/16 [00:00<?, ?it/s]
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#      (p,q)          AIC
# 0   (0, 3) -7502.118264
# 1   (0, 1) -7502.081164
# 2   (2, 3) -7502.064207
# 3   (3, 0) -7501.997241
# 4   (3, 2) -7501.979595
# 5   (1, 0) -7501.728353
# 6   (2, 0) -7501.011858
# 7   (0, 2) -7500.576801
# 8   (1, 1) -7500.287410
# 9   (1, 3) -7500.155914
# 10  (3, 1) -7500.079065
# 11  (3, 3) -7500.004321
# 12  (2, 1) -7499.776250
# 13  (1, 2) -7498.947845
# 14  (0, 0) -7494.867943
# 15  (2, 2) -7489.948157

# %% [markdown]
# Best model is ARIMA(0,1,3).
#
# In the context of negative number, a value closer to zero is consider larger. Thus, moving from a more negative number to a less negative number is considered ascending. Hence, the larger the negative value away from 0, the smaller the AIC.

# %% [markdown]
# # Residual Analysis

# %%
arima_model = SARIMAX(train, order=(0,1,3), simple_differencing=False)
arima_model = arima_model.fit(disp=False)
arima_model.plot_diagnostics(figsize=(15,8))

# %%
residuals = arima_model.resid
pvalue = acorr_ljungbox(residuals, np.arange(1,20,1))
print(pvalue)
# Out:
#       lb_stat  lb_pvalue
# 1    0.006437   0.936053
# 2    0.017128   0.991472
# 3    0.019367   0.999287
# 4    0.084624   0.999130
# 5    3.569181   0.612946
# 6    4.273068   0.639776
# 7    5.940823   0.546676
# 8    8.600919   0.377071
# 9    8.726334   0.462910
# 10   8.732299   0.557684
# 11  11.714308   0.385496
# 12  11.790610   0.462639
# 13  12.452037   0.490970
# 14  12.517475   0.564819
# 15  12.783095   0.619047
# 16  13.998438   0.598830
# 17  14.077118   0.661636
# 18  17.220392   0.508005
# 19  17.869410   0.531177

# %% [markdown]
# Looks good. We can conclude that our residuals resemble white noise. That means our model captured the pattern effectively leaving just random white noise.

# %% [markdown]
# # Forecasting

# %%
def rolling_forecast(data: pd.Series, train_len: int, horizon: int, window: int, method: str) -> list:
    total_len = train_len + horizon
    predictions = []

    for i in range(train_len, total_len, window):
        train_data = data[:i]
        
        if method == 'mean':
            mean_val = np.mean(train_data.values)
            predictions.extend([mean_val] * window)
        
        elif method == 'ARIMA':
            model = SARIMAX(train_data, order=(0, 1, 3))
            res = model.fit(disp=False)
            forecast = res.get_forecast(steps=window)
            pred_mean = forecast.predicted_mean
            predictions.extend(pred_mean)
        
        if len(predictions) >= horizon:
            break

    return predictions[:horizon]

# %%
copy_data
# Out:
# array([[-1.78072127],
#        [-1.79051119],
#        [-1.79100429],
#        ...,
#        [ 2.91315341],
#        [ 2.97961912],
#        [ 2.98687444]])

# %% [markdown]
# # Predicting the next year stock prices of Apple Stock - From 2022-10-18 to 2023-10-31

# %%
TRAIN = len(train)
HORIZON = len(test)
WINDOW = 1

pred_arima = rolling_forecast(copy_data, TRAIN, HORIZON, WINDOW, 'ARIMA')
# Out:
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Drew\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
predicted_data = pd.DataFrame({'Actual Data': data['Adj Close'][-261:]})
predicted_data.head()
# Out:
#             Actual Data
# Date
# 2022-10-18   142.714233
# 2022-10-19   142.823425
# 2022-10-20   142.356827
# 2022-10-21   146.208862
# 2022-10-24   148.373138

# %%
predicted_data['Predicted Data'] = pred_arima
predicted_data.head()
# Out:
#             Actual Data  Predicted Data
# Date
# 2022-10-18   142.714233        2.091576
# 2022-10-19   142.823425        2.166139
# 2022-10-20   142.356827        2.137625
# 2022-10-21   146.208862        2.140984
# 2022-10-24   148.373138        2.252042

# %%
pred_arima = np.array(pred_arima)
pred_arima = pred_arima.reshape(-1,1)

# %%
pred_arima = np.dot(pred_arima, pca.components_)
pred_arima = scaler.inverse_transform(pred_arima)

# %%
pred_arima
# Out:
# array([[143.71712217, 142.21227088, 140.80042787],
#        [146.10102786, 144.57038839, 143.1783389 ],
#        [145.18940262, 143.66862477, 142.26900607],
#        [145.29677448, 143.77483512, 142.37610793],
#        [148.84750636, 147.28715654, 145.91791101],
#        [150.93883145, 149.35585848, 148.00397718],
#        [153.57199555, 151.96053803, 150.63051982],
#        [151.11905684, 149.53413426, 148.18374936],
#        [147.02334106, 145.48272436, 144.09833282],
#        [158.26217347, 156.59997941, 155.30890366],
#        [154.54388975, 152.92191865, 151.59997006],
#        [153.09994143, 151.49359041, 150.15965275],
#        [148.47235389, 146.91606233, 145.54370191],
#        [140.99204065, 139.51666824, 138.08219894],
#        [141.27939139, 139.80091053, 138.3688271 ],
#        [140.37989603, 138.91114556, 137.47159364],
#        [141.4182525 , 139.93826949, 138.50733902],
#        [137.06952735, 135.63658718, 134.16954933],
#        [148.65085764, 147.09263509, 145.72175678],
#        [151.18584786, 149.60020277, 148.25037243],
#        [149.66219279, 148.09303001, 146.7305488 ],
#        [152.54358908, 150.94325646, 149.60469942],
#        [150.25600099, 148.68041462, 147.32286379],
#        [152.24644211, 150.64932392, 149.30829967],
#        [153.07740773, 151.47130047, 150.13717572],
#        [149.79447536, 148.2238816 , 146.86249872],
#        [151.60095548, 150.01081991, 148.6644362 ],
#        [152.66977427, 151.06807663, 149.7305673 ],
#        [149.37639726, 147.8103261 , 146.44547194],
#        [146.10457981, 144.57390192, 143.18188192],
#        [143.59359627, 142.09008123, 140.67721259],
#        [149.93576878, 148.36364656, 147.00343684],
#        [149.77799046, 148.20757502, 146.84605527],
#        [148.87666444, 147.3159992 , 145.94699577],
#        [149.32000247, 147.75454137, 146.38921896],
#        [145.41110295, 143.88792682, 142.4901489 ],
#        [142.8894795 , 141.39358132, 139.97486642],
#        [144.38233984, 142.87029247, 141.46397275],
#        [144.56385832, 143.04984736, 141.64503478],
#        [145.72720331, 144.20060773, 142.80545438],
#        [148.29096042, 146.7366311 , 145.36276457],
#        [145.34855264, 143.82605315, 142.42775588],
#        [139.13094339, 137.67570361, 136.22578166],
#        [136.83229569, 135.4019218 , 133.93291422],
#        [134.59757025, 133.19137075, 131.7038083 ],
#        [133.87239147, 132.47403669, 130.98045309],
#        [137.37357672, 135.93734746, 134.47283413],
#        [133.97366375, 132.57421343, 131.0814707 ],
#        [133.15624169, 131.76563394, 130.26610416],
#        [131.70052249, 130.32566215, 128.81404557],
#        [128.76085229, 127.41779217, 125.88176757],
#        [131.3081904 , 129.93757416, 128.42270005],
#        [131.14225484, 129.77343362, 128.25718176],
#        [127.95374111, 126.61941201, 125.07668598],
#        [128.38453433, 127.04554507, 125.50639591],
#        [127.10527884, 125.78012807, 124.23035728],
#        [131.2500181 , 129.88003114, 128.36467403],
#        [179.33523802, 177.44508366, 176.32897712],
#        [180.57884099, 178.6752338 , 177.56945287],
#        [180.29553923, 178.3949967 , 177.28686352],
#        [181.43525614, 179.52238459, 178.42371445],
#        [182.90169063, 180.97295575, 179.88646139],
#        [181.27901937, 179.36783792, 178.26787056],
#        [180.33910144, 178.43808766, 177.33031618],
#        [179.09226185, 177.2047359 , 176.08661193],
#        [177.93333054, 176.05834148, 174.93059493],
#        [177.84175091, 175.96775252, 174.83924558],
#        [175.1045819 , 173.26019314, 172.10895955],
#        [174.91421258, 173.07188317, 171.91906894],
#        [175.12604297, 173.28142205, 172.13036665],
#        [173.15169812, 171.32843491, 170.16098656],
#        [169.69708089, 167.9111884 , 166.71505645],
#        [170.11213635, 168.32175395, 167.12906819],
#        [172.31763991, 170.50339922, 169.32902571]])

# %%
predicted_data['Predicted Data'] = pred_arima

# %%
predicted_data.head(20)
# Out:
#             Actual Data  Predicted Data
# Date
# 2022-10-18   142.714233      143.717122
# 2022-10-19   142.823425      146.101028
# 2022-10-20   142.356827      145.189403
# 2022-10-21   146.208862      145.296774
# 2022-10-24   148.373138      148.847506
# 2022-10-25   151.242340      150.938831
# 2022-10-26   148.273880      153.571996
# 2022-10-27   143.756668      151.119057
# 2022-10-28   154.617844      147.023341
# 2022-10-31   152.235107      158.262173
# 2022-11-01   149.564514      154.543890
# 2022-11-02   143.985016      153.099941
# 2022-11-03   137.879333      148.472354
# 2022-11-04   137.610840      140.992041
# 2022-11-07   138.147812      141.279391
# 2022-11-08   138.724594      140.379896
# 2022-11-09   134.120346      141.418252
# 2022-11-10   146.053650      137.069527
# 2022-11-11   148.867889      148.650858
# 2022-11-14   147.455780      151.185848

# %%
fig, ax = pt.subplots(figsize=(10,8))

ax.plot(data['Adj Close'], label='Actual')
ax.plot(predicted_data['Predicted Data'], label='Predicted ARIMA(0,1,3)')
ax.set_title('Apple Stock Predictions')
ax.set_xlabel('Time')
ax.set_ylabel('Values')
ax.legend(loc=2)
ax.set_xlim(2200, 2475)
ax.set_ylim(110,200)
ax.axvspan(2214, 2475, color="#808080", alpha=0.4)
pt.xticks(np.arange(2200, 2475,15))
fig.autofmt_xdate()
pt.tight_layout()

# %%
mse = mean_squared_error(predicted_data['Actual Data'], predicted_data['Predicted Data'])
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 12.370975412016769

# %%
mae = mean_absolute_error(predicted_data['Actual Data'], predicted_data['Predicted Data'])
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 2.815627033488276

# %%
var = predicted_data['Predicted Data'].std()**2
print(f' Variance: {var}')
# Out:
#  Variance: 347.6528035977425

# %%
fig, ax = pt.subplots(figsize=(10,8))

X = ['MSE', 'MAE']
y = [12.33, 2.813]

ax.bar(X,y, width=0.4)
ax.set_title('Evaluation')
ax.set_xlabel('Metrics')
ax.set_ylabel('Value')

for index, value in enumerate(y):
    pt.text(x=index, y=value + 0.1, s=str(value), ha='center')

pt.tight_layout()

# %% [markdown]
# The performance of the model seems fairly good. The model is able to fit the data very well without overfitting and its able to capture the pattern. Also, it has a low MSE and MAE scoring.
